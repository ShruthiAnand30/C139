# %% [markdown]
# <a href="https://colab.research.google.com/github/ShruthiAnand30/C139/blob/main/C138.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kaggle

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-9036be6c-1351-46ec-926c-f773dd41ab0c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9036be6c-1351-46ec-926c-f773dd41ab0c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"shruthianandraman","key":"fa1160398a84ea03d049c415f68f45e9"}'}

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d tmdb/tmdb-movie-metadata
# Out:
# ...
#  79% 7.00M/8.89M [00:00<00:00, 70.6MB/s]
# 100% 8.89M/8.89M [00:00<00:00, 29.5MB/s]

# %%
# !unzip tmdb-movie-metadata.zip
# Out:
# Archive:  tmdb-movie-metadata.zip
#   inflating: tmdb_5000_credits.csv
#   inflating: tmdb_5000_movies.csv

# %%
import pandas as pd
import numpy as np
df1 = pd.read_csv("tmdb_5000_credits.csv")
df2 = pd.read_csv("tmdb_5000_movies.csv")
df1.head(10)
# Out:
#    movie_id  ...                                               crew
# 0     19995  ...  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1       285  ...  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2    206647  ...  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3     49026  ...  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4     49529  ...  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
# 5       559  ...  [{"credit_id": "52fe4252c3a36847f80151a5", "de...
# 6     38757  ...  [{"credit_id": "52fe46db9251416c91062101", "de...
# 7     99861  ...  [{"credit_id": "55d5f7d4c3a3683e7e0016eb", "de...
# 8       767  ...  [{"credit_id": "52fe4273c3a36847f801fab1", "de...
# 9    209112  ...  [{"credit_id": "553bf23692514135c8002886", "de...
#
# [10 rows x 4 columns]

# %%
df2.head()
# Out:
#       budget  ... vote_count
# 0  237000000  ...      11800
# 1  300000000  ...       4500
# 2  245000000  ...       4466
# 3  250000000  ...       9106
# 4  260000000  ...       2124
#
# [5 rows x 20 columns]

# %%
df1.columns = ["id","title","cast","crew"]
df2 = df2.merge(df1,on="id")
df2.head()
# Out:
#       budget  ...                                               crew
# 0  237000000  ...  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  300000000  ...  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  245000000  ...  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  250000000  ...  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  260000000  ...  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
#
# [5 rows x 23 columns]
# ...

# %%
m = df2['vote_count'].quantile(0.9)
print(m)
# Out:
# 1838.4000000000015

# %%
C = df2['vote_average'].mean()
print(C)
# Out:
# 6.092171559442011

# %%
q_movies = df2.copy().loc[df2["vote_count"]>=m]
print(q_movies.shape)
# Out:
# (481, 23)

# %%
def weighted_rating(x,m = m,C = C):
  v = x["vote_count"]
  R = x["vote_average"]
  return (v / (v+m)) * R + (m / (v+m)) * C
q_movies["score"] = q_movies.apply(weighted_rating,axis = 1)

# %%
q_movies = q_movies.sort_values("score",ascending = False )
q_movies[["original_title","vote_count", "vote_average", "score"]].head(10)
# Out:
#                                      original_title  ...     score
# 1881                       The Shawshank Redemption  ...  8.059258
# 662                                      Fight Club  ...  7.939256
# 65                                  The Dark Knight  ...  7.920020
# 3232                                   Pulp Fiction  ...  7.904645
# 96                                        Inception  ...  7.863239
# 3337                                  The Godfather  ...  7.851236
# 95                                     Interstellar  ...  7.809479
# 809                                    Forrest Gump  ...  7.803188
# 329   The Lord of the Rings: The Return of the King  ...  7.727243
# 1990                        The Empire Strikes Back  ...  7.697884
#
# [10 rows x 4 columns]

# %%
import plotly.express as px
fig = px.bar((q_movies.head(10).sort_values("score", ascending = False)),x = "score", y = "original_title", orientation ="h")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
